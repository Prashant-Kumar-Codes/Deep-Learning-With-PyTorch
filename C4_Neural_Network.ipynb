# %% [markdown]
# #### Important Topics
# 1. Data (load and prepare)
# 2. Build Model
# 3. Fitting the model to data (traiing)
# 4. Making predictions and evaluating a model (inference)
# 5. Saving and Loading Model
# 6. Finalizing the model

# %%
import torch
from torch import nn # nn contains all of PyTorch's building blocks for Neural Network
import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.4.1+cpu'

# %% [markdown]
# ## Data - Loading and Preparing
#
# Data can be almost anything... in machine learning.
# * Excel Spreadsheed
# * Images of any kind
# * Videos - Youtube, Insta, TV shows etc.
# * Audio - Songs, Podcasts etc
# * DNA
# * Text
#
# Machine learning is a game of two parts:
#
# 1. Get data into a numerical representation
# 2. Build a model to learn patterns in that numerical representation.
#
#
# To showcase this, let's create some *known* data usng the linear regression formula.
#
# We'll use a linear regression formula to make a straight line with known **parameters**.

# %%
# creating known parameters
weight = 0.7
bias = 0.3

# create 
start = 0
end = 1
step = 0.02
X = torch.arange(start, end, step).unsqueeze(dim=1)     # unsqueeze will add extra dimesnion 
Y = weight * X + bias

X[:5], Y[:5], len(X), len(Y)
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560]]),
#  50,
#  50)

# %% [markdown]
# ### Splitting data into training/test datasets

# %%
train_split = int(0.8 * len(X))
X_train, Y_train = X[:train_split], Y[:train_split]
X_test, Y_test = X[train_split:], Y[train_split:]

# %%
print(f'Length of X_train: {len(X_train)}')
print(f'Length of Y_train: {len(Y_train)}')
print(f'Length of X_test: {len(X_test)}')
print(f'Length of Y_test: {len(Y_test)}')
# Out:
# Length of X_train: 40
# Length of Y_train: 40
# Length of X_test: 10
# Length of Y_test: 10

# %%
plt.scatter(X_train, Y_train, s=3)
